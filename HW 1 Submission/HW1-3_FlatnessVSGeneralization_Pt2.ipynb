# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import numpy as np
import copy
from torch.nn.utils import parameters_to_vector, vector_to_parameters
from torch.autograd import Variable
import pandas as pd

# %%
train_data = torchvision.datasets.MNIST(root = "./data", #preprocess the MNIST dataset
                                       train = True,
                                       download = True,
                                       transform = transforms.ToTensor()
                                      )

test_data = torchvision.datasets.MNIST(root = "./data",
                                      train = False,
                                      transform = transforms.ToTensor()
                                     )
print("test data size is: ", len(train_data), "\nTrain Data size is: ",len(test_data))
# Out:
# test data size is:  60000
# Train Data size is:  10000

# %%
def train_loader(batch_size):
    train_loader = torch.utils.data.DataLoader(dataset=train_data, 
                                           batch_size = batch_size, 
                                           shuffle=True)
    return train_loader


def test_loader(batch_size):
    test_loader = torch.utils.data.DataLoader(dataset=test_data, 
                                          batch_size=batch_size, 
                                          shuffle=False)
    return test_loader

# %%
class Model(nn.Module):
  def __init__(self,):
        super(Model, self).__init__()
        self.fc1 = nn.Linear(784, 256)
        self.fc2 = nn.Linear(256, 10)
        
  def forward(self, x):
        # flatten as one dimension
        x = x.reshape(x.shape[0], -1)
        x = F.relu(self.fc1(x))
        x = self.fc2(x)
        return x

# %%
def trainFunc(model,num_epochs,train_batch_size):
    model.train()
    print('strated')
    train_load = train_loader(train_batch_size)
    n_total_steps = len(train_load)
    train_losses = []
    train_epoch = []
    train_acc = []
    not_converged =True
    epoch = 0
    sensitivity=[]
    while not_converged:
        epoch += 1
        n_correct = 0
        n_samples = 0
        lossSum =0
        for i, (images, labels) in enumerate(train_load):  
            images, labels = Variable(images),Variable(labels)
            
            optimizer.zero_grad()
            
            # Forward pass
            prediction = model(images)

            images.requires_grad = True

            loss = loss_func(prediction, labels)
            lossSum += loss
            loss.backward()
            optimizer.step()

            #Calculation for sensitivity
            froGrad=0
            count =0 
            for p in model.parameters():
                grad = 0.0
                if p.grad is not None:
                    grad = p.grad
                    froGrad_norm = torch.linalg.norm(grad).numpy()
                    froGrad += froGrad_norm
                    count += 1
            
            sensitivity.append(froGrad/count)

            _, predicted = torch.max(prediction.data, 1)
            n_samples += labels.size(0)
            n_correct += (predicted == labels).sum().item()
            acc = 100.0 * n_correct / n_samples

            train_losses.append(loss.item())
            train_acc.append(acc)
            train_epoch.append(epoch)
            if (i+1) % 10 == 0:
                print (f'Train O/P: Epoch [{epoch}/{num_epochs}], Step [{i+1}/{n_total_steps}], Loss: {loss.item():.4f}',end= '\r',flush = True)
                if epoch == num_epochs:
                        print("Max Epoch Reached")
                        not_converged = False
                elif (epoch > 5) and  (train_losses[-1] < 0.001):
                    if abs(train_losses[-3] - train_losses[-2]) < 1.0e-05 and abs(train_losses[-2] - train_losses[-1]) < 1.0e-05:
                        print("Convergeance reached for loss:",train_losses[-1])
                        not_converged = False
                        
        trainAvgLoss = lossSum/i+1
        print("Train Avg loss:",trainAvgLoss)
                        
    return train_epoch,train_losses,train_acc,sensitivity,trainAvgLoss

# %%
def testFunc(model,loss_func,test_batch_size): 
    test_load = test_loader(test_batch_size)
    model.eval()
    with torch.no_grad():
        n_correct = 0
        n_samples = 0
        testLoss = 0
        count = 0
        for images, labels in test_load:
            images, labels = Variable(images),Variable(labels)
            
            prediction = model(images)
            testLoss += loss_func(prediction,labels).item()
            # max returns (value ,index)
            _, predicted = torch.max(prediction.data, 1)
            n_samples += labels.size(0)
            n_correct += (predicted == labels).sum().item()
            count += 1
    netTest_loss = testLoss/count
    netTest_acc1 = 100.0 * n_correct / n_samples
    print(f'Accuracy of the network on the test images: {netTest_acc1}% & Test Loss: {netTest_loss} ',end= '\r',flush = True)
    return netTest_acc1, netTest_loss

# %%
batchArr = np.linspace (10,1510,5)
print(batchArr)
# Out:
# [  10.  385.  760. 1135. 1510.]

# %%
modelsTrainEpochArr = []
modelsTrainLossArr = []
modelsTrainAccArr = []
modelsTestLossArr = []
modelsTestAccArr = []
modelsSensitivityArr = []

temModel = Model ()

# %%
a=[]
for k in temModel.parameters():
    a.append(torch.numel(k))

print(f'Total no of parameters in Model :{np.sum(a)}')

for i in range (len(batchArr)):
    torch.manual_seed(1)
    j=copy.deepcopy(i) 
    j = Model()
    loss_func = nn.CrossEntropyLoss()
    
    optimizer = torch.optim.Adam(j.parameters(), lr=1e-3, weight_decay= 1e-4)
    
    max_epochs = 5
    train_batch_size = int(batchArr[i])

    train_epoch,train_losses,train_acc,sensitivity,tvgLoss = trainFunc(j,max_epochs,train_batch_size)
    test_batch_size = int(batchArr[i])
    testAcc, testLoss = testFunc(j,loss_func,test_batch_size)
    
    modelsTrainEpochArr.append(train_epoch)
    modelsTrainLossArr.append(train_losses)
    modelsTrainAccArr.append(train_acc)
    modelsTestAccArr.append(testAcc)
    modelsTestLossArr.append(testLoss)
    modelsSensitivityArr.append(sensitivity)
# Out:
# Total no of parameters in Model :203530
# strated
# Train Avg loss: tensor(1.2096, grad_fn=<AddBackward0>)
# Train Avg loss: tensor(1.0947, grad_fn=<AddBackward0>)
# Train Avg loss: tensor(1.0716, grad_fn=<AddBackward0>)
# Train Avg loss: tensor(1.0604, grad_fn=<AddBackward0>)
# Max Epoch Reached[5/5], Step [10/6000], Loss: 0.0064
# Max Epoch Reached[5/5], Step [20/6000], Loss: 0.0128
# Max Epoch Reached[5/5], Step [30/6000], Loss: 0.0370
# Max Epoch Reached[5/5], Step [40/6000], Loss: 0.0175
# Max Epoch Reached[5/5], Step [50/6000], Loss: 0.0036
# Max Epoch Reached[5/5], Step [60/6000], Loss: 0.2064
# Max Epoch Reached[5/5], Step [70/6000], Loss: 0.0006
# Max Epoch Reached[5/5], Step [80/6000], Loss: 0.0003
# Max Epoch Reached[5/5], Step [90/6000], Loss: 0.2606
# Max Epoch Reached[5/5], Step [100/6000], Loss: 0.0052
# Max Epoch Reached[5/5], Step [110/6000], Loss: 0.0015
# Max Epoch Reached[5/5], Step [120/6000], Loss: 0.0472
# Max Epoch Reached[5/5], Step [130/6000], Loss: 0.0341
# Max Epoch Reached[5/5], Step [140/6000], Loss: 0.0068
# Max Epoch Reached[5/5], Step [150/6000], Loss: 0.0496
# Max Epoch Reached[5/5], Step [160/6000], Loss: 0.0008
# Max Epoch Reached[5/5], Step [170/6000], Loss: 0.0007
# Max Epoch Reached[5/5], Step [180/6000], Loss: 0.0042
# Max Epoch Reached[5/5], Step [190/6000], Loss: 0.0011
# Max Epoch Reached[5/5], Step [200/6000], Loss: 0.0709
# Max Epoch Reached[5/5], Step [210/6000], Loss: 0.2174
# Max Epoch Reached[5/5], Step [220/6000], Loss: 0.1764
# Max Epoch Reached[5/5], Step [230/6000], Loss: 0.0054
# Max Epoch Reached[5/5], Step [240/6000], Loss: 0.1246
# Max Epoch Reached[5/5], Step [250/6000], Loss: 0.0016
# Max Epoch Reached[5/5], Step [260/6000], Loss: 0.0010
# Max Epoch Reached[5/5], Step [270/6000], Loss: 0.0071
# Max Epoch Reached[5/5], Step [280/6000], Loss: 0.2228
# Max Epoch Reached[5/5], Step [290/6000], Loss: 0.0026
# Max Epoch Reached[5/5], Step [300/6000], Loss: 0.0007
# Max Epoch Reached[5/5], Step [310/6000], Loss: 0.0128
# Max Epoch Reached[5/5], Step [320/6000], Loss: 0.0198
# Max Epoch Reached[5/5], Step [330/6000], Loss: 0.0009
# Max Epoch Reached[5/5], Step [340/6000], Loss: 0.0153
# Max Epoch Reached[5/5], Step [350/6000], Loss: 0.0033
# Max Epoch Reached[5/5], Step [360/6000], Loss: 0.0008
# Max Epoch Reached[5/5], Step [370/6000], Loss: 0.1019
# Max Epoch Reached[5/5], Step [380/6000], Loss: 0.0553
# Max Epoch Reached[5/5], Step [390/6000], Loss: 0.2521
# Max Epoch Reached[5/5], Step [400/6000], Loss: 0.0369
# Max Epoch Reached[5/5], Step [410/6000], Loss: 0.0230
# Max Epoch Reached[5/5], Step [420/6000], Loss: 0.0916
# Max Epoch Reached[5/5], Step [430/6000], Loss: 0.0045
# Max Epoch Reached[5/5], Step [440/6000], Loss: 0.0505
# Max Epoch Reached[5/5], Step [450/6000], Loss: 0.0023
# Max Epoch Reached[5/5], Step [460/6000], Loss: 0.0019
# Max Epoch Reached[5/5], Step [470/6000], Loss: 0.1063
# Max Epoch Reached[5/5], Step [480/6000], Loss: 0.0085
# Max Epoch Reached[5/5], Step [490/6000], Loss: 0.0328
# Max Epoch Reached[5/5], Step [500/6000], Loss: 0.0670
# Max Epoch Reached[5/5], Step [510/6000], Loss: 0.0124
# Max Epoch Reached[5/5], Step [520/6000], Loss: 0.5949
# Max Epoch Reached[5/5], Step [530/6000], Loss: 0.0059
# Max Epoch Reached[5/5], Step [540/6000], Loss: 0.0042
# Max Epoch Reached[5/5], Step [550/6000], Loss: 0.0066
# Max Epoch Reached[5/5], Step [560/6000], Loss: 0.0045
# Max Epoch Reached[5/5], Step [570/6000], Loss: 0.0097
# Max Epoch Reached[5/5], Step [580/6000], Loss: 0.0016
# Max Epoch Reached[5/5], Step [590/6000], Loss: 0.0021
# Max Epoch Reached[5/5], Step [600/6000], Loss: 0.0147
# Max Epoch Reached[5/5], Step [610/6000], Loss: 0.0496
# Max Epoch Reached[5/5], Step [620/6000], Loss: 0.0901
# Max Epoch Reached[5/5], Step [630/6000], Loss: 0.0171
# Max Epoch Reached[5/5], Step [640/6000], Loss: 0.0008
# Max Epoch Reached[5/5], Step [650/6000], Loss: 0.2212
# Max Epoch Reached[5/5], Step [660/6000], Loss: 0.1174
# Max Epoch Reached[5/5], Step [670/6000], Loss: 0.0233
# Max Epoch Reached[5/5], Step [680/6000], Loss: 0.0010
# Max Epoch Reached[5/5], Step [690/6000], Loss: 0.0053
# Max Epoch Reached[5/5], Step [700/6000], Loss: 0.0097
# Max Epoch Reached[5/5], Step [710/6000], Loss: 0.0017
# Max Epoch Reached[5/5], Step [720/6000], Loss: 0.0998
# Max Epoch Reached[5/5], Step [730/6000], Loss: 0.0023
# Max Epoch Reached[5/5], Step [740/6000], Loss: 0.0071
# Max Epoch Reached[5/5], Step [750/6000], Loss: 0.0381
# Max Epoch Reached[5/5], Step [760/6000], Loss: 0.0002
# Max Epoch Reached[5/5], Step [770/6000], Loss: 0.0085
# Max Epoch Reached[5/5], Step [780/6000], Loss: 0.0043
# Max Epoch Reached[5/5], Step [790/6000], Loss: 0.0208
# Max Epoch Reached[5/5], Step [800/6000], Loss: 0.0055
# Max Epoch Reached[5/5], Step [810/6000], Loss: 0.0007
# Max Epoch Reached[5/5], Step [820/6000], Loss: 0.0742
# Max Epoch Reached[5/5], Step [830/6000], Loss: 0.0021
# Max Epoch Reached[5/5], Step [840/6000], Loss: 0.0007
# Max Epoch Reached[5/5], Step [850/6000], Loss: 0.0169
# Max Epoch Reached[5/5], Step [860/6000], Loss: 0.0614
# Max Epoch Reached[5/5], Step [870/6000], Loss: 0.0006
# Max Epoch Reached[5/5], Step [880/6000], Loss: 0.0001
# Max Epoch Reached[5/5], Step [890/6000], Loss: 0.0217
# Max Epoch Reached[5/5], Step [900/6000], Loss: 0.0334
# Max Epoch Reached[5/5], Step [910/6000], Loss: 0.0065
# Max Epoch Reached[5/5], Step [920/6000], Loss: 0.0070
# Max Epoch Reached[5/5], Step [930/6000], Loss: 0.1653
# Max Epoch Reached[5/5], Step [940/6000], Loss: 0.0141
# Max Epoch Reached[5/5], Step [950/6000], Loss: 0.0578
# Max Epoch Reached[5/5], Step [960/6000], Loss: 0.0172
# Max Epoch Reached[5/5], Step [970/6000], Loss: 0.0037
# Max Epoch Reached[5/5], Step [980/6000], Loss: 0.0239
# Max Epoch Reached[5/5], Step [990/6000], Loss: 0.0230
# Max Epoch Reached[5/5], Step [1000/6000], Loss: 0.0186
# Max Epoch Reached[5/5], Step [1010/6000], Loss: 0.1899
# Max Epoch Reached[5/5], Step [1020/6000], Loss: 0.0012
# Max Epoch Reached[5/5], Step [1030/6000], Loss: 0.0512
# Max Epoch Reached[5/5], Step [1040/6000], Loss: 0.0143
# Max Epoch Reached[5/5], Step [1050/6000], Loss: 0.0118
# Max Epoch Reached[5/5], Step [1060/6000], Loss: 0.1322
# Max Epoch Reached[5/5], Step [1070/6000], Loss: 0.0257
# Max Epoch Reached[5/5], Step [1080/6000], Loss: 0.0003
# Max Epoch Reached[5/5], Step [1090/6000], Loss: 0.0104
# Max Epoch Reached[5/5], Step [1100/6000], Loss: 0.0006
# Max Epoch Reached[5/5], Step [1110/6000], Loss: 0.0094
# Max Epoch Reached[5/5], Step [1120/6000], Loss: 0.0059
# Max Epoch Reached[5/5], Step [1130/6000], Loss: 0.0048
# Max Epoch Reached[5/5], Step [1140/6000], Loss: 0.0004
# Max Epoch Reached[5/5], Step [1150/6000], Loss: 0.0550
# Max Epoch Reached[5/5], Step [1160/6000], Loss: 0.0598
# Max Epoch Reached[5/5], Step [1170/6000], Loss: 0.0514
# Max Epoch Reached[5/5], Step [1180/6000], Loss: 0.1862
# Max Epoch Reached[5/5], Step [1190/6000], Loss: 0.0006
# Max Epoch Reached[5/5], Step [1200/6000], Loss: 0.1222
# Max Epoch Reached[5/5], Step [1210/6000], Loss: 0.2955
# Max Epoch Reached[5/5], Step [1220/6000], Loss: 0.0063
# Max Epoch Reached[5/5], Step [1230/6000], Loss: 0.0044
# Max Epoch Reached[5/5], Step [1240/6000], Loss: 0.1200
# Max Epoch Reached[5/5], Step [1250/6000], Loss: 0.0110
# Max Epoch Reached[5/5], Step [1260/6000], Loss: 0.0021
# Max Epoch Reached[5/5], Step [1270/6000], Loss: 0.0043
# Max Epoch Reached[5/5], Step [1280/6000], Loss: 0.0029
# Max Epoch Reached[5/5], Step [1290/6000], Loss: 0.0110
# Max Epoch Reached[5/5], Step [1300/6000], Loss: 0.0195
# Max Epoch Reached[5/5], Step [1310/6000], Loss: 0.0008
# Max Epoch Reached[5/5], Step [1320/6000], Loss: 0.1973
# Max Epoch Reached[5/5], Step [1330/6000], Loss: 0.0316
# Max Epoch Reached[5/5], Step [1340/6000], Loss: 0.0007
# Max Epoch Reached[5/5], Step [1350/6000], Loss: 0.0002
# Max Epoch Reached[5/5], Step [1360/6000], Loss: 0.0007
# Max Epoch Reached[5/5], Step [1370/6000], Loss: 0.0066
# Max Epoch Reached[5/5], Step [1380/6000], Loss: 0.1036
# Max Epoch Reached[5/5], Step [1390/6000], Loss: 0.0075
# Max Epoch Reached[5/5], Step [1400/6000], Loss: 0.0431
# Max Epoch Reached[5/5], Step [1410/6000], Loss: 0.0141
# Max Epoch Reached[5/5], Step [1420/6000], Loss: 0.0103
# Max Epoch Reached[5/5], Step [1430/6000], Loss: 0.0120
# Max Epoch Reached[5/5], Step [1440/6000], Loss: 0.0101
# Max Epoch Reached[5/5], Step [1450/6000], Loss: 0.0017
# Max Epoch Reached[5/5], Step [1460/6000], Loss: 0.0096
# Max Epoch Reached[5/5], Step [1470/6000], Loss: 0.0003
# Max Epoch Reached[5/5], Step [1480/6000], Loss: 0.0657
# Max Epoch Reached[5/5], Step [1490/6000], Loss: 0.1278
# Max Epoch Reached[5/5], Step [1500/6000], Loss: 0.0217
# Max Epoch Reached[5/5], Step [1510/6000], Loss: 0.1209
# Max Epoch Reached[5/5], Step [1520/6000], Loss: 0.0026
# Max Epoch Reached[5/5], Step [1530/6000], Loss: 0.1522
# Max Epoch Reached[5/5], Step [1540/6000], Loss: 0.0074
# Max Epoch Reached[5/5], Step [1550/6000], Loss: 0.0530
# Max Epoch Reached[5/5], Step [1560/6000], Loss: 0.0119
# Max Epoch Reached[5/5], Step [1570/6000], Loss: 0.0013
# Max Epoch Reached[5/5], Step [1580/6000], Loss: 0.0084
# Max Epoch Reached[5/5], Step [1590/6000], Loss: 0.0010
# Max Epoch Reached[5/5], Step [1600/6000], Loss: 0.0238
# Max Epoch Reached[5/5], Step [1610/6000], Loss: 0.0574
# Max Epoch Reached[5/5], Step [1620/6000], Loss: 0.0043
# Max Epoch Reached[5/5], Step [1630/6000], Loss: 0.0090
# Max Epoch Reached[5/5], Step [1640/6000], Loss: 0.0088
# Max Epoch Reached[5/5], Step [1650/6000], Loss: 0.0141
# Max Epoch Reached[5/5], Step [1660/6000], Loss: 0.0034
# Max Epoch Reached[5/5], Step [1670/6000], Loss: 0.0054
# Max Epoch Reached[5/5], Step [1680/6000], Loss: 0.0022
# Max Epoch Reached[5/5], Step [1690/6000], Loss: 0.0118
# Max Epoch Reached[5/5], Step [1700/6000], Loss: 0.0863
# Max Epoch Reached[5/5], Step [1710/6000], Loss: 0.3049
# Max Epoch Reached[5/5], Step [1720/6000], Loss: 0.0080
# Max Epoch Reached[5/5], Step [1730/6000], Loss: 0.3745
# Max Epoch Reached[5/5], Step [1740/6000], Loss: 0.4992
# Max Epoch Reached[5/5], Step [1750/6000], Loss: 0.1453
# Max Epoch Reached[5/5], Step [1760/6000], Loss: 0.0009
# Max Epoch Reached[5/5], Step [1770/6000], Loss: 0.0100
# Max Epoch Reached[5/5], Step [1780/6000], Loss: 0.0062
# Max Epoch Reached[5/5], Step [1790/6000], Loss: 0.0955
# Max Epoch Reached[5/5], Step [1800/6000], Loss: 0.0365
# Max Epoch Reached[5/5], Step [1810/6000], Loss: 0.0159
# Max Epoch Reached[5/5], Step [1820/6000], Loss: 0.0084
# Max Epoch Reached[5/5], Step [1830/6000], Loss: 0.0009
# Max Epoch Reached[5/5], Step [1840/6000], Loss: 0.0067
# Max Epoch Reached[5/5], Step [1850/6000], Loss: 0.0124
# Max Epoch Reached[5/5], Step [1860/6000], Loss: 0.1401
# Max Epoch Reached[5/5], Step [1870/6000], Loss: 0.5975
# Max Epoch Reached[5/5], Step [1880/6000], Loss: 0.0016
# Max Epoch Reached[5/5], Step [1890/6000], Loss: 0.0044
# Max Epoch Reached[5/5], Step [1900/6000], Loss: 0.5929
# Max Epoch Reached[5/5], Step [1910/6000], Loss: 0.0058
# Max Epoch Reached[5/5], Step [1920/6000], Loss: 0.2612
# Max Epoch Reached[5/5], Step [1930/6000], Loss: 0.0234
# Max Epoch Reached[5/5], Step [1940/6000], Loss: 0.0022
# Max Epoch Reached[5/5], Step [1950/6000], Loss: 0.0012
# Max Epoch Reached[5/5], Step [1960/6000], Loss: 0.2138
# Max Epoch Reached[5/5], Step [1970/6000], Loss: 0.0020
# Max Epoch Reached[5/5], Step [1980/6000], Loss: 0.0305
# Max Epoch Reached[5/5], Step [1990/6000], Loss: 0.0662
# Max Epoch Reached[5/5], Step [2000/6000], Loss: 0.3295
# Max Epoch Reached[5/5], Step [2010/6000], Loss: 0.0075
# Max Epoch Reached[5/5], Step [2020/6000], Loss: 0.0225
# Max Epoch Reached[5/5], Step [2030/6000], Loss: 0.0043
# Max Epoch Reached[5/5], Step [2040/6000], Loss: 0.3377
# Max Epoch Reached[5/5], Step [2050/6000], Loss: 0.0019
# Max Epoch Reached[5/5], Step [2060/6000], Loss: 0.0326
# Max Epoch Reached[5/5], Step [2070/6000], Loss: 0.2187
# Max Epoch Reached[5/5], Step [2080/6000], Loss: 0.0043
# Max Epoch Reached[5/5], Step [2090/6000], Loss: 0.0122
# Max Epoch Reached[5/5], Step [2100/6000], Loss: 0.0445
# Max Epoch Reached[5/5], Step [2110/6000], Loss: 0.0410
# Max Epoch Reached[5/5], Step [2120/6000], Loss: 0.0003
# Max Epoch Reached[5/5], Step [2130/6000], Loss: 0.0022
# Max Epoch Reached[5/5], Step [2140/6000], Loss: 0.0006
# Max Epoch Reached[5/5], Step [2150/6000], Loss: 0.0273
# Max Epoch Reached[5/5], Step [2160/6000], Loss: 0.0957
# Max Epoch Reached[5/5], Step [2170/6000], Loss: 0.0269
# Max Epoch Reached[5/5], Step [2180/6000], Loss: 0.0107
# Max Epoch Reached[5/5], Step [2190/6000], Loss: 0.0031
# Max Epoch Reached[5/5], Step [2200/6000], Loss: 0.0067
# Max Epoch Reached[5/5], Step [2210/6000], Loss: 0.3200
# Max Epoch Reached[5/5], Step [2220/6000], Loss: 0.0082
# Max Epoch Reached[5/5], Step [2230/6000], Loss: 0.0223
# Max Epoch Reached[5/5], Step [2240/6000], Loss: 0.0017
# Max Epoch Reached[5/5], Step [2250/6000], Loss: 0.0018
# Max Epoch Reached[5/5], Step [2260/6000], Loss: 0.1871
# Max Epoch Reached[5/5], Step [2270/6000], Loss: 0.0030
# Max Epoch Reached[5/5], Step [2280/6000], Loss: 0.1323
# Max Epoch Reached[5/5], Step [2290/6000], Loss: 0.0029
# Max Epoch Reached[5/5], Step [2300/6000], Loss: 0.0539
# Max Epoch Reached[5/5], Step [2310/6000], Loss: 0.0024
# Max Epoch Reached[5/5], Step [2320/6000], Loss: 0.0412
# Max Epoch Reached[5/5], Step [2330/6000], Loss: 0.0001
# Max Epoch Reached[5/5], Step [2340/6000], Loss: 0.0037
# Max Epoch Reached[5/5], Step [2350/6000], Loss: 0.0046
# Max Epoch Reached[5/5], Step [2360/6000], Loss: 0.0991
# Max Epoch Reached[5/5], Step [2370/6000], Loss: 0.0103
# Max Epoch Reached[5/5], Step [2380/6000], Loss: 0.0222
# Max Epoch Reached[5/5], Step [2390/6000], Loss: 0.1812
# Max Epoch Reached[5/5], Step [2400/6000], Loss: 0.0862
# Max Epoch Reached[5/5], Step [2410/6000], Loss: 0.0655
# Max Epoch Reached[5/5], Step [2420/6000], Loss: 0.0003
# Max Epoch Reached[5/5], Step [2430/6000], Loss: 0.0028
# Max Epoch Reached[5/5], Step [2440/6000], Loss: 0.0258
# Max Epoch Reached[5/5], Step [2450/6000], Loss: 0.0880
# Max Epoch Reached[5/5], Step [2460/6000], Loss: 0.0392
# Max Epoch Reached[5/5], Step [2470/6000], Loss: 0.0015
# Max Epoch Reached[5/5], Step [2480/6000], Loss: 0.0141
# Max Epoch Reached[5/5], Step [2490/6000], Loss: 0.0018
# Max Epoch Reached[5/5], Step [2500/6000], Loss: 0.0038
# Max Epoch Reached[5/5], Step [2510/6000], Loss: 0.1349
# Max Epoch Reached[5/5], Step [2520/6000], Loss: 0.0065
# Max Epoch Reached[5/5], Step [2530/6000], Loss: 0.0022
# Max Epoch Reached[5/5], Step [2540/6000], Loss: 0.0077
# Max Epoch Reached[5/5], Step [2550/6000], Loss: 0.0022
# Max Epoch Reached[5/5], Step [2560/6000], Loss: 0.0071
# Max Epoch Reached[5/5], Step [2570/6000], Loss: 0.4192
# Max Epoch Reached[5/5], Step [2580/6000], Loss: 0.0028
# Max Epoch Reached[5/5], Step [2590/6000], Loss: 0.0003
# Max Epoch Reached[5/5], Step [2600/6000], Loss: 0.0064
# Max Epoch Reached[5/5], Step [2610/6000], Loss: 0.0148
# Max Epoch Reached[5/5], Step [2620/6000], Loss: 0.0036
# Max Epoch Reached[5/5], Step [2630/6000], Loss: 0.4508
# Max Epoch Reached[5/5], Step [2640/6000], Loss: 0.0013
# Max Epoch Reached[5/5], Step [2650/6000], Loss: 0.0003
# Max Epoch Reached[5/5], Step [2660/6000], Loss: 0.3808
# Max Epoch Reached[5/5], Step [2670/6000], Loss: 0.0086
# Max Epoch Reached[5/5], Step [2680/6000], Loss: 0.0045
# Max Epoch Reached[5/5], Step [2690/6000], Loss: 0.0708
# Max Epoch Reached[5/5], Step [2700/6000], Loss: 0.0011
# Max Epoch Reached[5/5], Step [2710/6000], Loss: 0.0029
# Max Epoch Reached[5/5], Step [2720/6000], Loss: 0.0761
# Max Epoch Reached[5/5], Step [2730/6000], Loss: 0.0067
# Max Epoch Reached[5/5], Step [2740/6000], Loss: 0.0019
# Max Epoch Reached[5/5], Step [2750/6000], Loss: 0.0017
# Max Epoch Reached[5/5], Step [2760/6000], Loss: 0.0052
# Max Epoch Reached[5/5], Step [2770/6000], Loss: 0.1897
# Max Epoch Reached[5/5], Step [2780/6000], Loss: 0.0077
# Max Epoch Reached[5/5], Step [2790/6000], Loss: 0.1916
# Max Epoch Reached[5/5], Step [2800/6000], Loss: 0.1682
# Max Epoch Reached[5/5], Step [2810/6000], Loss: 0.0040
# Max Epoch Reached[5/5], Step [2820/6000], Loss: 0.0076
# Max Epoch Reached[5/5], Step [2830/6000], Loss: 0.0221
# Max Epoch Reached[5/5], Step [2840/6000], Loss: 0.0372
# Max Epoch Reached[5/5], Step [2850/6000], Loss: 0.0042
# Max Epoch Reached[5/5], Step [2860/6000], Loss: 0.0134
# Max Epoch Reached[5/5], Step [2870/6000], Loss: 0.0033
# Max Epoch Reached[5/5], Step [2880/6000], Loss: 0.0126
# Max Epoch Reached[5/5], Step [2890/6000], Loss: 0.2600
# Max Epoch Reached[5/5], Step [2900/6000], Loss: 0.0208
# Max Epoch Reached[5/5], Step [2910/6000], Loss: 0.0019
# Max Epoch Reached[5/5], Step [2920/6000], Loss: 0.0185
# Max Epoch Reached[5/5], Step [2930/6000], Loss: 0.0481
# Max Epoch Reached[5/5], Step [2940/6000], Loss: 0.0025
# Max Epoch Reached[5/5], Step [2950/6000], Loss: 0.3653
# Max Epoch Reached[5/5], Step [2960/6000], Loss: 0.0040
# Max Epoch Reached[5/5], Step [2970/6000], Loss: 0.0004
# Max Epoch Reached[5/5], Step [2980/6000], Loss: 0.0009
# Max Epoch Reached[5/5], Step [2990/6000], Loss: 0.0212
# Max Epoch Reached[5/5], Step [3000/6000], Loss: 0.1245
# Max Epoch Reached[5/5], Step [3010/6000], Loss: 0.0439
# Max Epoch Reached[5/5], Step [3020/6000], Loss: 0.3620
# Max Epoch Reached[5/5], Step [3030/6000], Loss: 0.0134
# Max Epoch Reached[5/5], Step [3040/6000], Loss: 0.0323
# Max Epoch Reached[5/5], Step [3050/6000], Loss: 0.0746
# Max Epoch Reached[5/5], Step [3060/6000], Loss: 0.2527
# Max Epoch Reached[5/5], Step [3070/6000], Loss: 0.0681
# Max Epoch Reached[5/5], Step [3080/6000], Loss: 0.0076
# Max Epoch Reached[5/5], Step [3090/6000], Loss: 0.0907
# Max Epoch Reached[5/5], Step [3100/6000], Loss: 0.0235
# Max Epoch Reached[5/5], Step [3110/6000], Loss: 0.0001
# Max Epoch Reached[5/5], Step [3120/6000], Loss: 0.0078
# Max Epoch Reached[5/5], Step [3130/6000], Loss: 0.0176
# Max Epoch Reached[5/5], Step [3140/6000], Loss: 0.0093
# Max Epoch Reached[5/5], Step [3150/6000], Loss: 0.0010
# Max Epoch Reached[5/5], Step [3160/6000], Loss: 0.0016
# Max Epoch Reached[5/5], Step [3170/6000], Loss: 0.1116
# Max Epoch Reached[5/5], Step [3180/6000], Loss: 0.0307
# Max Epoch Reached[5/5], Step [3190/6000], Loss: 0.0030
# Max Epoch Reached[5/5], Step [3200/6000], Loss: 0.0280
# Max Epoch Reached[5/5], Step [3210/6000], Loss: 0.0368
# Max Epoch Reached[5/5], Step [3220/6000], Loss: 0.0015
# Max Epoch Reached[5/5], Step [3230/6000], Loss: 0.2623
# Max Epoch Reached[5/5], Step [3240/6000], Loss: 0.0025
# Max Epoch Reached[5/5], Step [3250/6000], Loss: 0.0014
# Max Epoch Reached[5/5], Step [3260/6000], Loss: 0.0037
# Max Epoch Reached[5/5], Step [3270/6000], Loss: 0.0028
# Max Epoch Reached[5/5], Step [3280/6000], Loss: 0.0032
# Max Epoch Reached[5/5], Step [3290/6000], Loss: 0.1451
# Max Epoch Reached[5/5], Step [3300/6000], Loss: 0.0042
# Max Epoch Reached[5/5], Step [3310/6000], Loss: 0.0488
# Max Epoch Reached[5/5], Step [3320/6000], Loss: 0.0063
# Max Epoch Reached[5/5], Step [3330/6000], Loss: 0.1064
# Max Epoch Reached[5/5], Step [3340/6000], Loss: 0.1091
# Max Epoch Reached[5/5], Step [3350/6000], Loss: 0.0193
# Max Epoch Reached[5/5], Step [3360/6000], Loss: 0.0030
# Max Epoch Reached[5/5], Step [3370/6000], Loss: 0.0014
# Max Epoch Reached[5/5], Step [3380/6000], Loss: 0.0019
# Max Epoch Reached[5/5], Step [3390/6000], Loss: 0.0199
# Max Epoch Reached[5/5], Step [3400/6000], Loss: 0.0137
# Max Epoch Reached[5/5], Step [3410/6000], Loss: 0.1568
# Max Epoch Reached[5/5], Step [3420/6000], Loss: 0.0059
# Max Epoch Reached[5/5], Step [3430/6000], Loss: 0.0051
# Max Epoch Reached[5/5], Step [3440/6000], Loss: 0.0061
# Max Epoch Reached[5/5], Step [3450/6000], Loss: 0.0107
# Max Epoch Reached[5/5], Step [3460/6000], Loss: 0.3913
# Max Epoch Reached[5/5], Step [3470/6000], Loss: 0.0009
# Max Epoch Reached[5/5], Step [3480/6000], Loss: 0.0003
# Max Epoch Reached[5/5], Step [3490/6000], Loss: 0.0117
# Max Epoch Reached[5/5], Step [3500/6000], Loss: 0.0120
# Max Epoch Reached[5/5], Step [3510/6000], Loss: 0.0102
# Max Epoch Reached[5/5], Step [3520/6000], Loss: 0.0268
# Max Epoch Reached[5/5], Step [3530/6000], Loss: 0.0107
# Max Epoch Reached[5/5], Step [3540/6000], Loss: 0.5427
# Max Epoch Reached[5/5], Step [3550/6000], Loss: 0.0248
# Max Epoch Reached[5/5], Step [3560/6000], Loss: 0.0035
# Max Epoch Reached[5/5], Step [3570/6000], Loss: 0.0012
# Max Epoch Reached[5/5], Step [3580/6000], Loss: 0.0020
# Max Epoch Reached[5/5], Step [3590/6000], Loss: 0.0214
# Max Epoch Reached[5/5], Step [3600/6000], Loss: 0.0094
# Max Epoch Reached[5/5], Step [3610/6000], Loss: 0.0220
# Max Epoch Reached[5/5], Step [3620/6000], Loss: 0.0172
# Max Epoch Reached[5/5], Step [3630/6000], Loss: 0.0153
# Max Epoch Reached[5/5], Step [3640/6000], Loss: 0.0034
# Max Epoch Reached[5/5], Step [3650/6000], Loss: 0.0010
# Max Epoch Reached[5/5], Step [3660/6000], Loss: 0.0719
# Max Epoch Reached[5/5], Step [3670/6000], Loss: 0.0361
# Max Epoch Reached[5/5], Step [3680/6000], Loss: 0.2965
# Max Epoch Reached[5/5], Step [3690/6000], Loss: 0.0435
# Max Epoch Reached[5/5], Step [3700/6000], Loss: 0.0003
# Max Epoch Reached[5/5], Step [3710/6000], Loss: 0.0007
# Max Epoch Reached[5/5], Step [3720/6000], Loss: 0.0025
# Max Epoch Reached[5/5], Step [3730/6000], Loss: 0.8516
# Max Epoch Reached[5/5], Step [3740/6000], Loss: 0.0080
# Max Epoch Reached[5/5], Step [3750/6000], Loss: 0.0391
# Max Epoch Reached[5/5], Step [3760/6000], Loss: 0.0087
# Max Epoch Reached[5/5], Step [3770/6000], Loss: 0.0028
# Max Epoch Reached[5/5], Step [3780/6000], Loss: 0.0021
# Max Epoch Reached[5/5], Step [3790/6000], Loss: 0.0024
# Max Epoch Reached[5/5], Step [3800/6000], Loss: 0.0107
# Max Epoch Reached[5/5], Step [3810/6000], Loss: 1.1406
# Max Epoch Reached[5/5], Step [3820/6000], Loss: 0.0135
# Max Epoch Reached[5/5], Step [3830/6000], Loss: 0.0007
# Max Epoch Reached[5/5], Step [3840/6000], Loss: 0.1621
# Max Epoch Reached[5/5], Step [3850/6000], Loss: 0.0015
# Max Epoch Reached[5/5], Step [3860/6000], Loss: 0.0064
# Max Epoch Reached[5/5], Step [3870/6000], Loss: 0.0087
# Max Epoch Reached[5/5], Step [3880/6000], Loss: 0.0152
# Max Epoch Reached[5/5], Step [3890/6000], Loss: 0.0675
# Max Epoch Reached[5/5], Step [3900/6000], Loss: 0.0027
# Max Epoch Reached[5/5], Step [3910/6000], Loss: 0.0715
# Max Epoch Reached[5/5], Step [3920/6000], Loss: 0.0003
# Max Epoch Reached[5/5], Step [3930/6000], Loss: 0.0006
# Max Epoch Reached[5/5], Step [3940/6000], Loss: 0.1766
# Max Epoch Reached[5/5], Step [3950/6000], Loss: 0.0440
# Max Epoch Reached[5/5], Step [3960/6000], Loss: 0.0712
# Max Epoch Reached[5/5], Step [3970/6000], Loss: 0.0059
# Max Epoch Reached[5/5], Step [3980/6000], Loss: 0.0031
# Max Epoch Reached[5/5], Step [3990/6000], Loss: 0.0142
# Max Epoch Reached[5/5], Step [4000/6000], Loss: 0.0126
# Max Epoch Reached[5/5], Step [4010/6000], Loss: 0.1298
# Max Epoch Reached[5/5], Step [4020/6000], Loss: 0.0078
# Max Epoch Reached[5/5], Step [4030/6000], Loss: 0.0161
# Max Epoch Reached[5/5], Step [4040/6000], Loss: 0.0086
# Max Epoch Reached[5/5], Step [4050/6000], Loss: 0.1415
# Max Epoch Reached[5/5], Step [4060/6000], Loss: 0.0050
# Max Epoch Reached[5/5], Step [4070/6000], Loss: 0.0009
# Max Epoch Reached[5/5], Step [4080/6000], Loss: 0.0234
# Max Epoch Reached[5/5], Step [4090/6000], Loss: 0.0042
# Max Epoch Reached[5/5], Step [4100/6000], Loss: 0.0681
# Max Epoch Reached[5/5], Step [4110/6000], Loss: 0.0004
# Max Epoch Reached[5/5], Step [4120/6000], Loss: 0.1275
# Max Epoch Reached[5/5], Step [4130/6000], Loss: 0.0454
# Max Epoch Reached[5/5], Step [4140/6000], Loss: 0.0050
# Max Epoch Reached[5/5], Step [4150/6000], Loss: 0.0064
# Max Epoch Reached[5/5], Step [4160/6000], Loss: 0.0870
# Max Epoch Reached[5/5], Step [4170/6000], Loss: 0.0372
# Max Epoch Reached[5/5], Step [4180/6000], Loss: 0.3337
# Max Epoch Reached[5/5], Step [4190/6000], Loss: 0.0013
# Max Epoch Reached[5/5], Step [4200/6000], Loss: 0.3158
# Max Epoch Reached[5/5], Step [4210/6000], Loss: 0.0064
# Max Epoch Reached[5/5], Step [4220/6000], Loss: 0.1535
# Max Epoch Reached[5/5], Step [4230/6000], Loss: 0.0078
# Max Epoch Reached[5/5], Step [4240/6000], Loss: 0.0127
# Max Epoch Reached[5/5], Step [4250/6000], Loss: 0.0520
# Max Epoch Reached[5/5], Step [4260/6000], Loss: 0.0006
# Max Epoch Reached[5/5], Step [4270/6000], Loss: 0.0037
# Max Epoch Reached[5/5], Step [4280/6000], Loss: 0.0048
# Max Epoch Reached[5/5], Step [4290/6000], Loss: 0.0021
# Max Epoch Reached[5/5], Step [4300/6000], Loss: 0.0025
# Max Epoch Reached[5/5], Step [4310/6000], Loss: 0.0015
# Max Epoch Reached[5/5], Step [4320/6000], Loss: 0.0096
# Max Epoch Reached[5/5], Step [4330/6000], Loss: 0.0160
# Max Epoch Reached[5/5], Step [4340/6000], Loss: 0.0009
# Max Epoch Reached[5/5], Step [4350/6000], Loss: 0.1501
# Max Epoch Reached[5/5], Step [4360/6000], Loss: 0.0021
# Max Epoch Reached[5/5], Step [4370/6000], Loss: 0.0091
# Max Epoch Reached[5/5], Step [4380/6000], Loss: 0.0005
# Max Epoch Reached[5/5], Step [4390/6000], Loss: 0.0064
# Max Epoch Reached[5/5], Step [4400/6000], Loss: 0.0027
# Max Epoch Reached[5/5], Step [4410/6000], Loss: 0.0019
# Max Epoch Reached[5/5], Step [4420/6000], Loss: 0.0028
# Max Epoch Reached[5/5], Step [4430/6000], Loss: 0.0029
# Max Epoch Reached[5/5], Step [4440/6000], Loss: 0.0050
# Max Epoch Reached[5/5], Step [4450/6000], Loss: 0.0010
# Max Epoch Reached[5/5], Step [4460/6000], Loss: 0.0322
# Max Epoch Reached[5/5], Step [4470/6000], Loss: 0.0009
# Max Epoch Reached[5/5], Step [4480/6000], Loss: 0.0017
# Max Epoch Reached[5/5], Step [4490/6000], Loss: 0.0171
# Max Epoch Reached[5/5], Step [4500/6000], Loss: 0.0238
# Max Epoch Reached[5/5], Step [4510/6000], Loss: 0.0019
# Max Epoch Reached[5/5], Step [4520/6000], Loss: 0.0007
# Max Epoch Reached[5/5], Step [4530/6000], Loss: 0.0026
# Max Epoch Reached[5/5], Step [4540/6000], Loss: 0.0081
# Max Epoch Reached[5/5], Step [4550/6000], Loss: 0.0030
# Max Epoch Reached[5/5], Step [4560/6000], Loss: 0.0305
# Max Epoch Reached[5/5], Step [4570/6000], Loss: 0.0304
# Max Epoch Reached[5/5], Step [4580/6000], Loss: 0.0044
# Max Epoch Reached[5/5], Step [4590/6000], Loss: 0.3058
# Max Epoch Reached[5/5], Step [4600/6000], Loss: 0.0120
# Max Epoch Reached[5/5], Step [4610/6000], Loss: 0.0107
# Max Epoch Reached[5/5], Step [4620/6000], Loss: 0.0017
# Max Epoch Reached[5/5], Step [4630/6000], Loss: 0.0167
# Max Epoch Reached[5/5], Step [4640/6000], Loss: 0.1438
# Max Epoch Reached[5/5], Step [4650/6000], Loss: 0.0017
# Max Epoch Reached[5/5], Step [4660/6000], Loss: 0.4516
# Max Epoch Reached[5/5], Step [4670/6000], Loss: 0.0133
# Max Epoch Reached[5/5], Step [4680/6000], Loss: 0.0520
# Max Epoch Reached[5/5], Step [4690/6000], Loss: 0.0585
# Max Epoch Reached[5/5], Step [4700/6000], Loss: 0.0119
# Max Epoch Reached[5/5], Step [4710/6000], Loss: 0.0223
# Max Epoch Reached[5/5], Step [4720/6000], Loss: 0.0290
# Max Epoch Reached[5/5], Step [4730/6000], Loss: 0.1299
# Max Epoch Reached[5/5], Step [4740/6000], Loss: 0.0205
# Max Epoch Reached[5/5], Step [4750/6000], Loss: 0.0955
# Max Epoch Reached[5/5], Step [4760/6000], Loss: 0.0216
# Max Epoch Reached[5/5], Step [4770/6000], Loss: 0.0054
# Max Epoch Reached[5/5], Step [4780/6000], Loss: 0.0837
# Max Epoch Reached[5/5], Step [4790/6000], Loss: 0.0193
# Max Epoch Reached[5/5], Step [4800/6000], Loss: 0.1613
# Max Epoch Reached[5/5], Step [4810/6000], Loss: 0.0060
# Max Epoch Reached[5/5], Step [4820/6000], Loss: 0.4681
# Max Epoch Reached[5/5], Step [4830/6000], Loss: 0.0009
# Max Epoch Reached[5/5], Step [4840/6000], Loss: 0.0045
# Max Epoch Reached[5/5], Step [4850/6000], Loss: 0.0267
# Max Epoch Reached[5/5], Step [4860/6000], Loss: 0.0369
# Max Epoch Reached[5/5], Step [4870/6000], Loss: 0.0085
# Max Epoch Reached[5/5], Step [4880/6000], Loss: 0.1151
# Max Epoch Reached[5/5], Step [4890/6000], Loss: 0.0084
# Max Epoch Reached[5/5], Step [4900/6000], Loss: 0.0003
# Max Epoch Reached[5/5], Step [4910/6000], Loss: 0.0179
# Max Epoch Reached[5/5], Step [4920/6000], Loss: 0.0043
# Max Epoch Reached[5/5], Step [4930/6000], Loss: 0.2050
# Max Epoch Reached[5/5], Step [4940/6000], Loss: 0.0031
# Max Epoch Reached[5/5], Step [4950/6000], Loss: 0.0609
# Max Epoch Reached[5/5], Step [4960/6000], Loss: 0.0729
# Max Epoch Reached[5/5], Step [4970/6000], Loss: 0.1282
# Max Epoch Reached[5/5], Step [4980/6000], Loss: 0.1453
# Max Epoch Reached[5/5], Step [4990/6000], Loss: 0.0023
# Max Epoch Reached[5/5], Step [5000/6000], Loss: 0.0200
# Max Epoch Reached[5/5], Step [5010/6000], Loss: 0.0173
# Max Epoch Reached[5/5], Step [5020/6000], Loss: 0.0791
# Max Epoch Reached[5/5], Step [5030/6000], Loss: 0.0406
# Max Epoch Reached[5/5], Step [5040/6000], Loss: 0.0826
# Max Epoch Reached[5/5], Step [5050/6000], Loss: 0.0530
# Max Epoch Reached[5/5], Step [5060/6000], Loss: 0.0327
# Max Epoch Reached[5/5], Step [5070/6000], Loss: 0.0091
# Max Epoch Reached[5/5], Step [5080/6000], Loss: 0.2439
# Max Epoch Reached[5/5], Step [5090/6000], Loss: 0.0049
# Max Epoch Reached[5/5], Step [5100/6000], Loss: 0.0050
# Max Epoch Reached[5/5], Step [5110/6000], Loss: 0.0006
# Max Epoch Reached[5/5], Step [5120/6000], Loss: 0.0001
# Max Epoch Reached[5/5], Step [5130/6000], Loss: 0.0194
# Max Epoch Reached[5/5], Step [5140/6000], Loss: 0.0668
# Max Epoch Reached[5/5], Step [5150/6000], Loss: 0.0317
# Max Epoch Reached[5/5], Step [5160/6000], Loss: 0.0303
# Max Epoch Reached[5/5], Step [5170/6000], Loss: 0.0091
# Max Epoch Reached[5/5], Step [5180/6000], Loss: 0.0104
# Max Epoch Reached[5/5], Step [5190/6000], Loss: 0.1981
# Max Epoch Reached[5/5], Step [5200/6000], Loss: 0.0164
# Max Epoch Reached[5/5], Step [5210/6000], Loss: 0.0867
# Max Epoch Reached[5/5], Step [5220/6000], Loss: 0.2593
# Max Epoch Reached[5/5], Step [5230/6000], Loss: 0.0019
# Max Epoch Reached[5/5], Step [5240/6000], Loss: 0.0635
# Max Epoch Reached[5/5], Step [5250/6000], Loss: 0.0038
# Max Epoch Reached[5/5], Step [5260/6000], Loss: 0.0256
# Max Epoch Reached[5/5], Step [5270/6000], Loss: 0.0016
# Max Epoch Reached[5/5], Step [5280/6000], Loss: 0.0954
# Max Epoch Reached[5/5], Step [5290/6000], Loss: 0.1223
# Max Epoch Reached[5/5], Step [5300/6000], Loss: 0.0569
# Max Epoch Reached[5/5], Step [5310/6000], Loss: 0.0064
# Max Epoch Reached[5/5], Step [5320/6000], Loss: 0.0070
# Max Epoch Reached[5/5], Step [5330/6000], Loss: 0.0099
# Max Epoch Reached[5/5], Step [5340/6000], Loss: 0.2350
# Max Epoch Reached[5/5], Step [5350/6000], Loss: 0.0009
# Max Epoch Reached[5/5], Step [5360/6000], Loss: 0.0017
# Max Epoch Reached[5/5], Step [5370/6000], Loss: 0.0273
# Max Epoch Reached[5/5], Step [5380/6000], Loss: 0.0088
# Max Epoch Reached[5/5], Step [5390/6000], Loss: 0.0046
# Max Epoch Reached[5/5], Step [5400/6000], Loss: 0.0007
# Max Epoch Reached[5/5], Step [5410/6000], Loss: 0.0176
# Max Epoch Reached[5/5], Step [5420/6000], Loss: 0.1134
# Max Epoch Reached[5/5], Step [5430/6000], Loss: 0.0052
# Max Epoch Reached[5/5], Step [5440/6000], Loss: 0.0016
# Max Epoch Reached[5/5], Step [5450/6000], Loss: 0.0216
# Max Epoch Reached[5/5], Step [5460/6000], Loss: 0.8881
# Max Epoch Reached[5/5], Step [5470/6000], Loss: 0.0036
# Max Epoch Reached[5/5], Step [5480/6000], Loss: 0.0379
# Max Epoch Reached[5/5], Step [5490/6000], Loss: 0.0047
# Max Epoch Reached[5/5], Step [5500/6000], Loss: 0.2631
# Max Epoch Reached[5/5], Step [5510/6000], Loss: 0.0025
# Max Epoch Reached[5/5], Step [5520/6000], Loss: 0.1740
# Max Epoch Reached[5/5], Step [5530/6000], Loss: 0.0062
# Max Epoch Reached[5/5], Step [5540/6000], Loss: 0.0114
# Max Epoch Reached[5/5], Step [5550/6000], Loss: 0.1703
# Max Epoch Reached[5/5], Step [5560/6000], Loss: 0.0159
# Max Epoch Reached[5/5], Step [5570/6000], Loss: 0.0321
# Max Epoch Reached[5/5], Step [5580/6000], Loss: 0.2179
# Max Epoch Reached[5/5], Step [5590/6000], Loss: 0.0140
# Max Epoch Reached[5/5], Step [5600/6000], Loss: 0.0115
# Max Epoch Reached[5/5], Step [5610/6000], Loss: 0.0008
# Max Epoch Reached[5/5], Step [5620/6000], Loss: 0.0085
# Max Epoch Reached[5/5], Step [5630/6000], Loss: 0.0371
# Max Epoch Reached[5/5], Step [5640/6000], Loss: 0.0072
# Max Epoch Reached[5/5], Step [5650/6000], Loss: 0.0176
# Max Epoch Reached[5/5], Step [5660/6000], Loss: 0.0004
# Max Epoch Reached[5/5], Step [5670/6000], Loss: 0.0147
# Max Epoch Reached[5/5], Step [5680/6000], Loss: 0.1035
# Max Epoch Reached[5/5], Step [5690/6000], Loss: 0.0480
# Max Epoch Reached[5/5], Step [5700/6000], Loss: 0.1537
# Max Epoch Reached[5/5], Step [5710/6000], Loss: 0.0175
# Max Epoch Reached[5/5], Step [5720/6000], Loss: 0.0064
# Max Epoch Reached[5/5], Step [5730/6000], Loss: 0.0022
# Max Epoch Reached[5/5], Step [5740/6000], Loss: 0.0025
# Max Epoch Reached[5/5], Step [5750/6000], Loss: 0.0241
# Max Epoch Reached[5/5], Step [5760/6000], Loss: 0.0661
# Max Epoch Reached[5/5], Step [5770/6000], Loss: 0.0312
# Max Epoch Reached[5/5], Step [5780/6000], Loss: 0.0010
# Max Epoch Reached[5/5], Step [5790/6000], Loss: 0.0800
# Max Epoch Reached[5/5], Step [5800/6000], Loss: 0.0126
# Max Epoch Reached[5/5], Step [5810/6000], Loss: 0.0753
# Max Epoch Reached[5/5], Step [5820/6000], Loss: 0.0081
# Max Epoch Reached[5/5], Step [5830/6000], Loss: 0.1513
# Max Epoch Reached[5/5], Step [5840/6000], Loss: 0.0599
# Max Epoch Reached[5/5], Step [5850/6000], Loss: 0.0144
# Max Epoch Reached[5/5], Step [5860/6000], Loss: 0.0083
# Max Epoch Reached[5/5], Step [5870/6000], Loss: 0.0020
# Max Epoch Reached[5/5], Step [5880/6000], Loss: 0.0066
# Max Epoch Reached[5/5], Step [5890/6000], Loss: 0.0075
# Max Epoch Reached[5/5], Step [5900/6000], Loss: 0.2762
# Max Epoch Reached[5/5], Step [5910/6000], Loss: 0.1177
# Max Epoch Reached[5/5], Step [5920/6000], Loss: 0.0007
# Max Epoch Reached[5/5], Step [5930/6000], Loss: 0.0054
# Max Epoch Reached[5/5], Step [5940/6000], Loss: 0.1050
# Max Epoch Reached[5/5], Step [5950/6000], Loss: 0.0003
# Max Epoch Reached[5/5], Step [5960/6000], Loss: 0.0080
# Max Epoch Reached[5/5], Step [5970/6000], Loss: 0.0029
# Max Epoch Reached[5/5], Step [5980/6000], Loss: 0.0072
# Max Epoch Reached[5/5], Step [5990/6000], Loss: 0.0271
# Max Epoch Reached[5/5], Step [6000/6000], Loss: 0.0126
# Train Avg loss: tensor(1.0543, grad_fn=<AddBackward0>)
# stratedy of the network on the test images: 97.67% & Test Loss: 0.07471130282194371
# Train Avg loss: tensor(1.5344, grad_fn=<AddBackward0>)
# Train Avg loss: tensor(1.2277, grad_fn=<AddBackward0>)
# Train Avg loss: tensor(1.1696, grad_fn=<AddBackward0>)
# Train Avg loss: tensor(1.1349, grad_fn=<AddBackward0>)
# Max Epoch Reached[5/5], Step [10/156], Loss: 0.0962
# Max Epoch Reached[5/5], Step [20/156], Loss: 0.0887
# Max Epoch Reached[5/5], Step [30/156], Loss: 0.0728
# Max Epoch Reached[5/5], Step [40/156], Loss: 0.1048
# Max Epoch Reached[5/5], Step [50/156], Loss: 0.1170
# Max Epoch Reached[5/5], Step [60/156], Loss: 0.0659
# Max Epoch Reached[5/5], Step [70/156], Loss: 0.0708
# Max Epoch Reached[5/5], Step [80/156], Loss: 0.1478
# Max Epoch Reached[5/5], Step [90/156], Loss: 0.0898
# Max Epoch Reached[5/5], Step [100/156], Loss: 0.1115
# Max Epoch Reached[5/5], Step [110/156], Loss: 0.1146
# Max Epoch Reached[5/5], Step [120/156], Loss: 0.1044
# Max Epoch Reached[5/5], Step [130/156], Loss: 0.0808
# Max Epoch Reached[5/5], Step [140/156], Loss: 0.0917
# Max Epoch Reached[5/5], Step [150/156], Loss: 0.1093
# Train Avg loss: tensor(1.1110, grad_fn=<AddBackward0>)
# stratedy of the network on the test images: 96.83% & Test Loss: 0.10708448828126375
# Train Avg loss: tensor(1.7285, grad_fn=<AddBackward0>)
# Train Avg loss: tensor(1.2841, grad_fn=<AddBackward0>)
# Train Avg loss: tensor(1.2250, grad_fn=<AddBackward0>)
# Train Avg loss: tensor(1.1879, grad_fn=<AddBackward0>)
# Max Epoch Reached[5/5], Step [10/79], Loss: 0.1644
# Max Epoch Reached[5/5], Step [20/79], Loss: 0.1470
# Max Epoch Reached[5/5], Step [30/79], Loss: 0.1494
# Max Epoch Reached[5/5], Step [40/79], Loss: 0.1716
# Max Epoch Reached[5/5], Step [50/79], Loss: 0.1375
# Max Epoch Reached[5/5], Step [60/79], Loss: 0.1457
# Max Epoch Reached[5/5], Step [70/79], Loss: 0.1233
# Train Avg loss: tensor(1.1595, grad_fn=<AddBackward0>)
# stratedy of the network on the test images: 95.8% & Test Loss: 0.15250348698879992
# Train Avg loss: tensor(1.9006, grad_fn=<AddBackward0>)
# Train Avg loss: tensor(1.3263, grad_fn=<AddBackward0>)
# Train Avg loss: tensor(1.2626, grad_fn=<AddBackward0>)
# Train Avg loss: tensor(1.2237, grad_fn=<AddBackward0>)
# Max Epoch Reached[5/5], Step [10/53], Loss: 0.2135
# Max Epoch Reached[5/5], Step [20/53], Loss: 0.1964
# Max Epoch Reached[5/5], Step [30/53], Loss: 0.1658
# Max Epoch Reached[5/5], Step [40/53], Loss: 0.1885
# Max Epoch Reached[5/5], Step [50/53], Loss: 0.1666
# Train Avg loss: tensor(1.1930, grad_fn=<AddBackward0>)
# stratedy of the network on the test images: 94.94% & Test Loss: 0.17748344441254935
# Train Avg loss: tensor(2.0601, grad_fn=<AddBackward0>)
# Train Avg loss: tensor(1.3628, grad_fn=<AddBackward0>)
# Train Avg loss: tensor(1.2886, grad_fn=<AddBackward0>)
# Train Avg loss: tensor(1.2479, grad_fn=<AddBackward0>)
# Max Epoch Reached[5/5], Step [10/40], Loss: 0.2079
# Max Epoch Reached[5/5], Step [20/40], Loss: 0.2256
# Max Epoch Reached[5/5], Step [30/40], Loss: 0.2045
# Max Epoch Reached[5/5], Step [40/40], Loss: 0.2184
# Train Avg loss: tensor(1.2168, grad_fn=<AddBackward0>)
# Accuracy of the network on the test images: 94.46% & Test Loss: 0.19492754553045546

# %%
def meanScore(dataArr):
    meanModelData = []
    for i in range (len(dataArr)):
        meanScore = np.mean(dataArr[i])
        meanModelData.append(meanScore)
    return meanModelData

def minScore(dataArr):
    minModelScore = []
    for i in range (len(dataArr)):
        minScore = np.mean(dataArr[i])
        minModelScore.append(minScore)
    return minModelScore

def maxScore(dataArr):
    maxModelScore = []
    for i in range (len(dataArr)):
        maxScore = np.max(dataArr[i])
        maxModelScore.append(maxScore)
    return maxModelScore

# %%
fig,ax=plt.subplots()
ax.plot(batchArr,minScore(modelsTrainLossArr),color="Blue", marker="o",linestyle='dashed')
ax.plot(batchArr,modelsTestLossArr,color="Blue", marker="v")
ax.legend(['Train Loss','Test Loss'],loc="upper right")
ax.set_xlabel("Batch",color="Green")
ax.set_ylabel("CrossEntropy Loss",color = "blue")
ax.set_title("Loss,Sensitivity Vs Batch Size",color="g")

ax2=ax.twinx()
ax2.plot(batchArr,minScore(modelsSensitivityArr),color="red")
ax2.set_xlabel("Batch",color="Green")
ax2.set_ylabel("Sensitivity",color = "red")
ax2.legend(['Sensitivity'],loc="center left")

plt.show()

# %%
fig,ax=plt.subplots()
ax.plot(batchArr,minScore(modelsTrainAccArr),color="Blue", marker="o",linestyle='dashed')
ax.plot(batchArr,modelsTestAccArr,color="Blue", marker="v")
ax.legend(['Train Acc','Test Acc'],loc="upper right")
ax.set_xlabel("Batch",color="Green")
ax.set_ylabel("Accuracy",color = "blue")
ax.set_title("Accuracy,Sensitivity Vs Batch Size",color="g")

ax2=ax.twinx()
ax2.plot(batchArr,minScore(modelsSensitivityArr),color="red")
ax2.set_xlabel("Batch",color="Green")
ax2.set_ylabel("Sensitivity",color = "red")
ax2.legend(['Sensitivity'],loc="center left")

plt.show()
